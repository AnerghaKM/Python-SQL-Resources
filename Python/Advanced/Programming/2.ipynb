# %% [markdown]
# 1. Write a function that takes a positive integer num and calculates how many dots exist in a pentagonal shape around the center dot on the Nth iteration.
# In the image below you can see the first iteration is only a single dot. On the second, there are 6 dots. On the third, there are 16 dots, and on the fourth there are 31 dots.
#
# Return the number of dots that exist in the whole pentagon on the Nth iteration.
# Examples
#
# pentagonal(1) ➞ 1
#
# pentagonal(2) ➞ 6
#
# pentagonal(3) ➞ 16
#
# pentagonal(8) ➞ 141

# %% [markdown]
# ![1py.PNG](attachment:1py.PNG)

# %%
def dot(num):
    out=1
    if num>=0:
        for i in range(num):
            out=out+(5*i)
        print(f"pentagonal({num}) ➞ {out}")
    else:
        print("Number should be positive")
for i in range(4):
    num=int(input("enter the number : "))
    dot(num)
# Out:
# enter the number : 1
# pentagonal(1) ➞ 1
# enter the number : 2
# pentagonal(2) ➞ 6
# enter the number : 3
# pentagonal(3) ➞ 16
# enter the number : 8
# pentagonal(8) ➞ 141

# %% [markdown]
# 2. Make a function that encrypts a given input with these steps:
#
# Input: &quot;apple&quot;
#
# Step 1: Reverse the input: &quot;elppa&quot;
#
# Step 2: Replace all vowels using the following chart:
#
# a =&gt; 0
#
# e =&gt; 1
#
# i =&gt; 2
#
# o =&gt; 2
#
# u =&gt; 3
#
# #&quot;1lpp0&quot;
#
# Step 3: Add &quot;aca&quot; to the end of the word: &quot;1lpp0aca&quot;
#
# Output: &quot;1lpp0aca&quot;
#
# Examples
#
# encrypt(&quot;banana&quot;) ➞ &quot;0n0n0baca&quot;
#
# encrypt(&quot;karaca&quot;) ➞ &quot;0c0r0kaca&quot;
#
# encrypt(&quot;burak&quot;) ➞ &quot;k0r3baca&quot;
#
# encrypt(&quot;alpaca&quot;) ➞ &quot;0c0pl0aca&quot;

# %%
def out(s):
    r=s[::-1]
    d={"a":0,"e":1,"i":2,"o":2,"u":3}
    p=""
    for i in r:
        if i in d.keys():
            p+=str(d[i])
        else:
            p+=i
    p=p+"aca"
    print(f"encrypt({s}) ➞ {p}")
for i in range(5):            
    s=input("input the word : ")
    out(s)
# Out:
# input the word : apple
# encrypt(apple) ➞ 1lpp0aca
# input the word : banana
# encrypt(banana) ➞ 0n0n0baca
# input the word : karaca
# encrypt(karaca) ➞ 0c0r0kaca
# input the word : burak
# encrypt(burak) ➞ k0r3baca
# input the word : alpaca
# encrypt(alpaca) ➞ 0c0pl0aca

# %%
d={"a":1,"e":2,"i":3,"o":4,"u":5}
print(d.keys())
print(d.values())
d["a"]
# Out:
# dict_keys(['a', 'e', 'i', 'o', 'u'])
# dict_values([1, 2, 3, 4, 5])
# 1

# %%
d={1:1000,"e":2,"i":3,"o":4,"u":5}
for i in range(2):
    if i in d.keys():
        print(d[i])
# Out:
# 1000

# %% [markdown]
# 3. Given the month and year as numbers, return whether that month contains a Friday 13th.
# (i.e You can check Python&#39;s datetime module)
#
# Examples
#
# has_friday_13(3, 2020) ➞ True
#
# has_friday_13(10, 2017) ➞ True
#
# has_friday_13(1, 1985) ➞ False

# %%
#calendar.weekday(year, month, day)
#Returns the day of the week (0 is Monday) for year (1970–…), month (1–12), day (1–31).
import calendar
def day(m,y):
    l=(calendar.weekday(y, m, 13))
    #print(l)
    #0-Monday,4-Friday
    if l==4:
        print(f"has_friday_13({month},{year}) ➞ True")
    else:
        print(f"has_friday_13({month},{year}) ➞ False")
for i in range(3):   
    m=int(input("enter the month : "))
    y=int(input("enter the year : "))
    day(m,y)
# Out:
# enter the month : 3
# enter the year : 2020
# has_friday_13(3,2020) ➞ True
# enter the month : 10
# enter the year : 2017
# has_friday_13(3,2020) ➞ True
# enter the month : 1
# enter the year : 1985
# has_friday_13(3,2020) ➞ False

# %%
import datetime
print(datetime.datetime(2020,3,13))
print(datetime.datetime(2020,3,13).strftime('%A'))
print(datetime.datetime(2020,3,13).strftime('%d'))  
print(datetime.datetime(2020,3,13).strftime('%m'))
print(datetime.datetime(2020,3,13).strftime('%y'))
print(datetime.datetime(2020,3,13).strftime('%w'))#week
# Out:
# 2020-03-13 00:00:00
# Friday
# 13
# 03
# 20
# 5

# %%
import datetime
def checkday(month,year):
    if datetime.datetime(year,month,13).strftime('%A') == 'Friday':
        print(f'has_friday_13{month,year} ➞ True')
    else:
        print(f'has_friday_13{month,year} ➞ False')
        
m=int(input("enter the month : "))
y=int(input("enter the year : "))
checkday(m,y)
# Out:
# enter the month : 03
# enter the year : 2020
# has_friday_13(3, 2020) ➞ True

# %% [markdown]
# 4. Write a regular expression that will help us count how many bad cookies are produced every day. You must use RegEx negative lookbehind.
# Example
#
# lst = [&quot;bad cookie&quot;, &quot;good cookie&quot;, &quot;bad cookie&quot;, &quot;good cookie&quot;, &quot;good cookie&quot;]
#
# pattern = &quot;yourregularexpressionhere&quot;
#
# len(re.findall(pattern, &quot;, &quot;.join(lst))) ➞ 2

# %%
import re
lst = ["bad cookie", "good cookie", "bad cookie", "good cookie", "good cookie"]
pattern = r'(?<!good)\scookie'# Regex Negative lookbehind expression
data = re.findall(pattern,' '.join(lst))
print(f'No of Bad cookies produced per day ➞ {len(data)}')
# Out:
# No of Bad cookies produced per day ➞ 2

# %% [markdown]
# 5. Given a list of words in the singular form, return a set of those words in the plural form if they appear more than once in the list.
# Examples
#
# pluralize([&quot;cow&quot;, &quot;pig&quot;, &quot;cow&quot;, &quot;cow&quot;]) ➞ { &quot;cows&quot;, &quot;pig&quot; }
#
# pluralize([&quot;table&quot;, &quot;table&quot;, &quot;table&quot;]) ➞ { &quot;tables&quot; }
#
# pluralize([&quot;chair&quot;, &quot;pencil&quot;, &quot;arm&quot;]) ➞ { &quot;chair&quot;, &quot;pencil&quot;, &quot;arm&quot; }

# %%
def setplural(l):
    d={}
    for i in l:
        if i not in d:
            d[i]=1
        else:
            d[i]+=1
    #print(d)
    s=set()
    #print(type(s),"type of set s")
    for key,value in d.items():
            
            if value>1:
                s.add(key+"s")
            elif value==1:
                s.add(key)
    print(f"pluralize({l}) ➞ {s}") 

for i in range(3):
    lim=int(input("enter the count of elements in list : "))
    l=[]
    for i in range(lim):
        ele=input("enter the count of element : ")
        l.append(ele)
    setplural(l)
# Out:
# enter the count of elements in list : 4
# enter the count of element : cow
# enter the count of element : pig
# enter the count of element : cow
# enter the count of element : cow
# pluralize(['cow', 'pig', 'cow', 'cow']) ➞ {'pig', 'cows'}
# enter the count of elements in list : 3
# enter the count of element : table
# enter the count of element : table
# enter the count of element : table
# pluralize(['table', 'table', 'table']) ➞ {'tables'}
# enter the count of elements in list : 3
# enter the count of element : chair
# enter the count of element : pencil
# enter the count of element : arm
# pluralize(['chair', 'pencil', 'arm']) ➞ {'chair', 'arm', 'pencil'}

# %%
d={1:1000,"e":2,"i":3,"o":4,"u":5}
for i in range(2):
    if i in d.keys():
        print(d[i])
# Out:
# 1000

# %%
d={1:1000,"e":1,"i":3,"o":4,"u":5}
            
for key, value in d.items():
    if value == 1:
        print(key)
# Out:
# e
